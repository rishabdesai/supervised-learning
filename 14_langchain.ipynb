# %%
# %pip install langchain langchain-openai langchain_ollama langchain-community dotenv

# %%
# import required packages
from dotenv import load_dotenv
import os
from langchain_openai import ChatOpenAI

# %%
# load all the keys from .env file
#load_dotenv()
load_dotenv(dotenv_path=".env")

# %%
# create an object of ChatOpenAI to access the LLM
llm = ChatOpenAI(model="gpt-4o", max_completion_tokens=100)

# %%
# prompt: input to the LLM
prompt = "how LLM works?"

# %%
# invoke the LLM to get the response
response = llm.invoke(prompt)

# %%
# read only the answer from the response
print(response.content)
# Out:
# A Large Language Model (LLM) works by utilizing a deep learning architecture, typically based on a neural network, to process and generate human-like text. Here's a high-level overview of how LLMs, like GPT (Generative Pre-trained Transformer), function:
#
# 1. **Architecture**: LLMs are primarily based on a type of neural network called the Transformer, which was introduced in the paper "Attention is All You Need." The Transformer architecture relies heavily on self-attention mechanisms to process
