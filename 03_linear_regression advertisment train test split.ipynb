# %%
#import required packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
#load the data
# data source: # https://www.kaggle.com/code/ashydv/sales-prediction-simple-linear-regression
df = pd.read_csv("advertising.csv")

# %%
# EDA = Exploratory data analysis
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
# get stats info
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
# read first few recordsw
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
# read last few records
df.tail()
# Out:
#         TV  Radio  Newspaper  Sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4

# %%
# visualize the data
plt.scatter(df['TV'],df['Sales'])

# %%
plt.scatter(df['Radio'],df['Sales'])

# %%
plt.scatter(df['Newspaper'],df['Sales'])

# %%
 # find correlation coefficient
df.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000

# %%
#split the data
# x = independent variable
x= df.drop('Sales', axis=1)
x
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y=df["Sales"]
y
# Out:
# 0      22.1
# 1      10.4
# 2      12.0
# 3      16.5
# 4      17.9
#        ...
# 195     7.6
# 196    14.0
# 197    14.8
# 198    25.5
# 199    18.4
# Name: Sales, Length: 200, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, train_size=0.8, random_state=123)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#get the prediction
y_pred = model.predict(x_test)
y_pred
# Out:
# array([15.76348766,  8.98558508, 13.92308986,  9.80445345, 15.13032992,
#        21.12309436, 14.64595599, 19.40106778, 16.73295901,  9.20728968,
#        10.87466244, 20.4805595 ,  8.30111746,  6.95592581,  5.41768903,
#        12.59527932, 15.56078011, 19.81856167,  7.98396271, 19.37197332,
#         7.84855288, 12.13625834,  9.6087248 ,  8.58783395, 21.71260505,
#         9.60112904, 13.37603395, 15.46248389, 11.42078416, 20.74075492,
#        11.73226609, 22.05858939, 24.72284661,  7.40571914, 17.0344549 ,
#        20.05837538, 20.59574652, 19.26586004, 16.8159113 , 10.41789125])

# %%
# Evaluate the mode

#MAE - Mean absolute Error
#MSE - Mean Squared Error
#RMSE - Root Mean Squared Error
#R2_Score and Score

# %%
#MAE - Mean absolute Error
from sklearn.metrics import mean_absolute_error

mea = mean_absolute_error(y_test, y_pred)
mea
# Out:
# 1.2707307309230793

# %%
#MSE - Mean Squared Error
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test,y_pred)
mse
# Out:
# 2.629702604149311

# %%
#RMSE - Root Mean Squared Error 
from sklearn.metrics import root_mean_squared_error

rmse = root_mean_squared_error(y_test, y_pred)
rmse
# Out:
# 1.6216357803617034

# %%
# R2_Score
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.9180169996276659

# %%
score = model.score(x_test, y_test)
score
# Out:
# 0.9180169996276659
